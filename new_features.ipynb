# %% [markdown]
# # Making new features

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
import plotly.express as px

# %%
# Do not touch me
df_fines = pd.read_csv("fines.csv", sep=',',skiprows=0,skipfooter=1, na_values=None,engine='python')
df_latlons = pd.read_csv("latlons.csv", sep=',', skiprows=0, skipfooter=1, na_values=None,engine='python')
df_addresses = pd.read_csv("addresses.csv", sep=',', skiprows=0, na_values=None,engine='python')

# %% [markdown]
# ## Join the tables

# %%
df_spatial = pd.merge(df_addresses, df_latlons,
                    how='inner', on='address')
df_spatial = pd.merge(df_fines, df_spatial,
                    how='inner', on='ticket_id')

# %%
len(df_spatial)
# Out:
# 16920

# %%
df_spatial.head(5)
# Out:
#    ticket_id                                     agency_name  \
# 0      22056  Buildings, Safety Engineering & Env Department
# 1      22062  Buildings, Safety Engineering & Env Department
# 2      22046  Buildings, Safety Engineering & Env Department
# 3      18735  Buildings, Safety Engineering & Env Department
# 4      18733  Buildings, Safety Engineering & Env Department
#
#      inspector_name                      violator_name  \
# 0   Sims, Martinzie  INVESTMENT INC., MIDWEST MORTGAGE
# 1   Sims, Martinzie                    SANDERS, DERRON
# 2   Sims, Martinzie                     KASIMU, UKWELI
# 3  Williams, Darrin    Rafee Auto Services L.L.C., RAF
# 4  Williams, Darrin    Rafee Auto Services L.L.C., RAF
#
#    violation_street_number violation_street_name  violation_zip_code  \
# 0                     2900                 TYLER                 NaN
# 1                     1449            LONGFELLOW                 NaN
# 2                     6478            NORTHFIELD                 NaN
# 3                     8228            MT ELLIOTT                 NaN
# 4                     8228            MT ELLIOTT                 NaN
#
#    mailing_address_str_number mailing_address_str_name       city  ...  \
# 0                         3.0                S. WICKER    CHICAGO  ...
# 1                     23658.0                 P.O. BOX    DETROIT  ...
# 2                      2755.0                  E. 17TH  LOG BEACH  ...
# 3                      8228.0              Mt. Elliott    Detroit  ...
# 4                      8228.0              Mt. Elliott    Detroit  ...
#
#   balance_due payment_date      payment_status collection_status  \
# 0       305.0          NaN  NO PAYMENT APPLIED               NaN
# 1         0.0          NaN  NO PAYMENT APPLIED               NaN
# 2       305.0          NaN  NO PAYMENT APPLIED               NaN
# 3       140.0          NaN  NO PAYMENT APPLIED               NaN
# 4       140.0          NaN  NO PAYMENT APPLIED               NaN
#
#   grafitti_status               compliance_detail compliance  \
# 0             NaN     non-compliant by no payment        0.0
# 1             NaN  not responsible by disposition        NaN
# 2             NaN     non-compliant by no payment        0.0
# 3             NaN     non-compliant by no payment        0.0
# 4             NaN     non-compliant by no payment        0.0
#
#                        address        lat        lon
# 0       2900 tyler, Detroit MI  42.390729 -83.124268
# 1  1449 longfellow, Detroit MI  42.380516 -83.096069
# 2  6478 northfield, Detroit MI  42.145257 -83.208233
# 3  8228 mt elliott, Detroit MI  42.388641 -83.037858
# 4  8228 mt elliott, Detroit MI  42.388641 -83.037858
#
# [5 rows x 37 columns]

# %%
list(df_spatial.columns)
# Out:
# ['ticket_id',
#  'agency_name',
#  'inspector_name',
#  'violator_name',
#  'violation_street_number',
#  'violation_street_name',
#  'violation_zip_code',
#  'mailing_address_str_number',
#  'mailing_address_str_name',
#  'city',
#  'state',
#  'zip_code',
#  'non_us_str_code',
#  'country',
#  'ticket_issued_date',
#  'hearing_date',
#  'violation_code',
#  'violation_description',
#  'disposition',
#  'fine_amount',
#  'admin_fee',
#  'state_fee',
#  'late_fee',
#  'discount_amount',
#  'clean_up_cost',
#  'judgment_amount',
#  'payment_amount',
#  'balance_due',
#  'payment_date',
#  'payment_status',
#  'collection_status',
#  'grafitti_status',
#  'compliance_detail',
#  'compliance',
#  'address',
#  'lat',
#  'lon']

# %%
df_spatial.iloc[6]
# Out:
# ticket_id                                                                 18743
# agency_name                      Buildings, Safety Engineering & Env Department
# inspector_name                                                 Williams, Darrin
# violator_name                                               Gardner Resale, GAR
# violation_street_number                                                    9100
# violation_street_name                                                  VAN DYKE
# violation_zip_code                                                          NaN
# mailing_address_str_number                                                 91.0
# mailing_address_str_name                                               Van Dyke
# city                                                                    Detroit
# state                                                                        MI
# zip_code                                                                  48213
# non_us_str_code                                                             NaN
# country                                                                     USA
# ticket_issued_date                                              7/28/2004 12:15
# hearing_date                                                    2/22/2005 15:00
# violation_code                                                       61-63.0600
# violation_description         Failed To Secure Permit For Lawful Use Of Buil...
# disposition                                              Responsible by Default
# fine_amount                                                                 750
# admin_fee                                                                    20
# state_fee                                                                    10
# late_fee                                                                   75.0
# discount_amount                                                               0
# clean_up_cost                                                                 0
# judgment_amount                                                           855.0
# payment_amount                                                              0.0
# balance_due                                                               855.0
# payment_date                                                                NaN
# payment_status                                               NO PAYMENT APPLIED
# collection_status                                                 IN COLLECTION
# grafitti_status                                                             NaN
# compliance_detail                                   non-compliant by no payment
# compliance                                                                  0.0
# address                                               9100 van dyke, Detroit MI
# lat                                                                   42.395765
# lon                                                                  -83.022333
# Name: 6, dtype: object

# %%
df_spatial[['ticket_id', 'disposition', 'compliance', 'compliance_detail', 'collection_status', 'payment_status']]
# Out:
#        ticket_id                   disposition  compliance  \
# 0          22056        Responsible by Default         0.0
# 1          22062  Not responsible by Dismissal         NaN
# 2          22046        Responsible by Default         0.0
# 3          18735        Responsible by Default         0.0
# 4          18733        Responsible by Default         0.0
# ...          ...                           ...         ...
# 16915      70928        Responsible by Default         0.0
# 16916      70738  Not responsible by Dismissal         NaN
# 16917      70737  SET-ASIDE (PENDING JUDGMENT)         NaN
# 16918      70826      Responsible by Admission         1.0
# 16919      71143  Responsible by Determination         0.0
#
#                                      compliance_detail collection_status  \
# 0                          non-compliant by no payment               NaN
# 1                       not responsible by disposition               NaN
# 2                          non-compliant by no payment               NaN
# 3                          non-compliant by no payment               NaN
# 4                          non-compliant by no payment               NaN
# ...                                                ...               ...
# 16915                      non-compliant by no payment               NaN
# 16916                   not responsible by disposition               NaN
# 16917  not responsible by pending judgment disposition               NaN
# 16918                     compliant by on-time payment               NaN
# 16919  non-compliant by late payment more than 1 month               NaN
#
#            payment_status
# 0      NO PAYMENT APPLIED
# 1      NO PAYMENT APPLIED
# 2      NO PAYMENT APPLIED
# 3      NO PAYMENT APPLIED
# 4      NO PAYMENT APPLIED
# ...                   ...
# 16915  NO PAYMENT APPLIED
# 16916  NO PAYMENT APPLIED
# 16917        PAID IN FULL
# 16918        PAID IN FULL
# 16919        PAID IN FULL
#
# [16920 rows x 6 columns]

# %%
df_fines.disposition.unique()
# Out:
# array(['Responsible by Default', 'Responsible by Determination',
#        'Not responsible by Dismissal',
#        'Not responsible by City Dismissal', 'PENDING JUDGMENT',
#        'Responsible by Admission', 'Not responsible by Determination',
#        'SET-ASIDE (PENDING JUDGMENT)'], dtype=object)

# %%
df_fines.payment_status.unique()
# Out:
# array(['NO PAYMENT APPLIED', 'PAID IN FULL', 'PARTIAL PAYMENT APPLIED'],
#       dtype=object)

# %%
df_fines.compliance_detail.unique()
# Out:
# array(['non-compliant by no payment',
#        'compliant by late payment within 1 month',
#        'not responsible by disposition',
#        'not responsible by pending judgment disposition',
#        'non-compliant by late payment more than 1 month',
#        'compliant by early payment', 'compliant by on-time payment',
#        'compliant by payment with no scheduled hearing',
#        'compliant by payment on unknown date'], dtype=object)

# %% [markdown]
# ## New spatial features
#
# Let's create clusters that will help us understand different quarters of the city
# - Use of K-means

# %%
color_scale = [(0, 'orange'), (1,'red')]

df_subset = 

fig = px.scatter_mapbox(df_spatial, 
                        lat="lat", 
                        lon="lon", 
                       # hover_name="Address", 
                        #hover_data=["Address", "Listed"],
                        #color="Listed",
                       # color_continuous_scale=color_scale,
                        #size="Listed",
                        zoom=8, 
                        height=800,
                        width=800)

fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
